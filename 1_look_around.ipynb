# %%
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
# %run "./load_clean.ipynb"

# %%
df = data_df
df.head()
# Out:
#   PassengerId HomePlanet CryoSleep  Cabin  Destination   Age    VIP  \
# 0     0001_01     Europa     False  B/0/P  TRAPPIST-1e  39.0  False
# 1     0002_01      Earth     False  F/0/S  TRAPPIST-1e  24.0  False
# 2     0003_01     Europa     False  A/0/S  TRAPPIST-1e  58.0   True
# 3     0003_02     Europa     False  A/0/S  TRAPPIST-1e  33.0  False
# 4     0004_01      Earth     False  F/1/S  TRAPPIST-1e  16.0  False
#
#    spend_room_service  spend_food_court  spend_shopping_mall  ...  \
# 0                 0.0               0.0                  0.0  ...
# 1               109.0               9.0                 25.0  ...
# 2                43.0            3576.0                  0.0  ...
# 3                 0.0            1283.0                371.0  ...
# 4               303.0              70.0                151.0  ...
#
#                 Name  Transported group_id  group_num cabin_deck cabin_num  \
# 0    Maham Ofracculy        False     0001         01          B         0
# ...

# %% [markdown]
# # Investigation
#
# We need to see what gaps we have here.

# %% [markdown]
# ## How many total and empties?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          8693 non-null   object
#  1   HomePlanet           8492 non-null   object
#  2   CryoSleep            8476 non-null   object
#  3   Cabin                8494 non-null   object
#  4   Destination          8511 non-null   object
#  5   Age                  8514 non-null   float64
#  6   VIP                  8490 non-null   object
#  7   spend_room_service   8512 non-null   float64
#  8   spend_food_court     8510 non-null   float64
#  9   spend_shopping_mall  8485 non-null   float64
#  10  spend_spa            8510 non-null   float64
#  11  spend_vr_deck        8505 non-null   float64
#  12  Name                 8493 non-null   object
#  13  Transported          8693 non-null   bool
#  14  group_id             8693 non-null   object
# ...

# %%
df[df['CryoSleep'].isna()]
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 92       0099_02      Earth       NaN    G/12/P  TRAPPIST-1e   2.0  False
# 98       0105_01      Earth       NaN    F/21/P  TRAPPIST-1e  27.0  False
# 104      0110_02     Europa       NaN     B/5/P  TRAPPIST-1e  40.0  False
# 111      0115_01       Mars       NaN    F/24/P  TRAPPIST-1e  26.0  False
# 152      0173_01      Earth       NaN    E/11/S  TRAPPIST-1e  58.0  False
# ...          ...        ...       ...       ...          ...   ...    ...
# 8620     9197_01     Europa       NaN   C/308/P  55 Cancri e  44.0  False
# 8651     9227_05      Earth       NaN  G/1498/P  TRAPPIST-1e   8.0  False
# 8664     9246_01      Earth       NaN  G/1490/S  TRAPPIST-1e  32.0  False
# 8675     9259_01      Earth       NaN  F/1893/P  TRAPPIST-1e  44.0  False
# 8687     9275_03     Europa       NaN    A/97/P  TRAPPIST-1e  30.0  False
#
#       spend_room_service  spend_food_court  spend_shopping_mall  ...  \
# ...

# %% [markdown]
# A fair number of our fields need either back-filling, inferring, defaulting or even dropping.

# %%
df.head()
# Out:
#   PassengerId HomePlanet CryoSleep  Cabin  Destination   Age    VIP  \
# 0     0001_01     Europa     False  B/0/P  TRAPPIST-1e  39.0  False
# 1     0002_01      Earth     False  F/0/S  TRAPPIST-1e  24.0  False
# 2     0003_01     Europa     False  A/0/S  TRAPPIST-1e  58.0   True
# 3     0003_02     Europa     False  A/0/S  TRAPPIST-1e  33.0  False
# 4     0004_01      Earth     False  F/1/S  TRAPPIST-1e  16.0  False
#
#    spend_room_service  spend_food_court  spend_shopping_mall  ...  \
# 0                 0.0               0.0                  0.0  ...
# 1               109.0               9.0                 25.0  ...
# 2                43.0            3576.0                  0.0  ...
# 3                 0.0            1283.0                371.0  ...
# 4               303.0              70.0                151.0  ...
#
#                 Name  Transported group_id  group_num cabin_deck cabin_num  \
# 0    Maham Ofracculy        False     0001         01          B         0
# ...

# %% [markdown]
# # Let's Visualize

# %%
def plot_sunburst(df, root_field, branch_field="Transported"):
    fig = px.sunburst(
        data_frame=df,
        title=root_field,
        path=[root_field, branch_field],  # Root, branches, leaves
        color=branch_field,
        # color_discrete_sequence=px.colors.qualitative.Pastel,
    )
    fig.update_traces(textinfo='label+percent entry')
    fig.update_layout(width=600, height=600)
    fig.show()

# %%
fields = [
    'HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP', 
   'Transported', 
   'group_id', 'group_num', 
   'cabin_deck', 'cabin_num', 'cabin_side',
#    'spend_total', 'spend_high_total', 'spend_low_total',
   ]

# for field in fields: plot_sunburst(df, field)

plot_sunburst(df, "CryoSleep")
# plot_sunburst(df, "HomePlanet")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rg/mb0r29s96sgc2j4j60fjp4jw0000gn/T/ipykernel_18335/3827416183.py in <module>
#       9 # for field in fields: plot_sunburst(df, field)
#      10
# ---> 11 plot_sunburst(df, "CryoSleep")
#      12 # plot_sunburst(df, "HomePlanet")
#
# /var/folders/rg/mb0r29s96sgc2j4j60fjp4jw0000gn/T/ipykernel_18335/3105327661.py in plot_sunburst(df, root_field, branch_field)
#       1 def plot_sunburst(df, root_field, branch_field="Transported"):
# ----> 2     fig = px.sunburst(
#       3         data_frame=df,
#       4         title=root_field,
#       5         path=[root_field, branch_field],  # Root, branches, leaves
#
# ...

# %%
def count_plot(field):
    px.histogram(df.sort_values(by=field), x=field, title=field, color="Transported", nbins=10).show()

    # val_counts = df[field].value_counts()
    # if len(val_counts) > 10 and field != "Age":
    #     px.line(val_counts, title=field).show()
    # else:
    #     px.histogram(df, x=field, title=field, color="Transported", nbins=10).show()

fields = [
    'HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP', 
   'Transported', 
   'group_id', 'group_num', 
   'cabin_deck', 'cabin_num', 'cabin_side',
#    'spend_total', 'spend_high_total', 'spend_low_total',
   ]

for field in fields: count_plot(field)

# %%
df.groupby("group_num").count()
# Out:
#            PassengerId  HomePlanet  CryoSleep  Cabin  Destination   Age   VIP  \
# group_num
# 01                6217        6076       6068   6083         6085  6095  6070
# 02                1412        1376       1370   1377         1384  1374  1381
# 03                 571         559        557    551          561   560   554
# 04                 231         225        225    225          225   227   229
# 05                 128         126        124    127          124   127   125
# 06                  75          72         74     75           74    75    74
# 07                  46          45         45     43           45    43    44
# 08                  13          13         13     13           13    13    13
#
#            spend_room_service  spend_food_court  spend_shopping_mall  ...  \
# group_num                                                             ...
# 01                       6081              6084                 6073  ...
# ...

# %%
df.groupby("group_num").size()
# Out:
# group_num
# 01    6217
# 02    1412
# 03     571
# 04     231
# 05     128
# 06      75
# 07      46
# 08      13
# dtype: int64

# %%
field = "group_num"
g_df = pd.DataFrame(df.groupby(field).size()).reset_index()
g_df.rename(columns={0:'count', field:'field'}, inplace=True)
g_df
# Out:
#   field  count
# 0    01   6217
# 1    02   1412
# 2    03    571
# 3    04    231
# 4    05    128
# 5    06     75
# 6    07     46
# 7    08     13

# %%
def pie_field_count(df, field, title):
    g_df = pd.DataFrame(df.groupby(field).size()).reset_index()
    g_df.rename(columns={0:'count'}, inplace=True)

    chart = px.pie(g_df, 
        values="count", 
        names=field, 
        title=title,
        width=800,                          #figure width in pixels
        height=600,                         #figure height in pixels
        hole=0.5,                           #represents the hole in middle of pie
        )
    chart.update_traces(
        textposition='outside', 
        textinfo='percent+label',
        marker=dict(line=dict(color='#000000', width=3)),
        # pull=[0, 0, 0.2, 0], 
        opacity=0.7, 
        # rotation=180,
        )

    chart.show()

# %%
pie_field_count(df, "group_num", "Members per GROUP_NUM")

# %%
dummied_df = pd.get_dummies(df.drop([
    'PassengerId', 'HomePlanet', 'CryoSleep', 
    'Cabin', 'Destination', 'Name', 
    'group_id', 'group_num', 'cabin_num'
    ], axis=1))
px.imshow(dummied_df.corr(), color_continuous_scale='curl')

# %% [markdown]
# ## Money / Wealth / Deck / Side
#
# Looking at the correlations there seems to be an indicator between
# **Transported** and
# - Money Spent (shopping mall and food court have negative correlations)
# - Deck (B and C have positive correlation)
# - Side of Ship (S has a positive correlation)
#
# It would make sense to organize a few features around these compounds.
# - deck_side (T_S, T_P, B_S, B_P, ...)
#
# Also to define:
# - Total Spend
#   - Total Spend High (room service, spa, vr deck)
#   - Total Spend Lo (food court, shopping mall)
# - In Group

# %% [markdown]
# ## Cabin number?
#
# Oddly the cabin number has some pattern in it. there are some cabins where 100% of the people were transported and others where there were large numbers of transported people. Perhaps there is a density component to this.
